# %% [markdown]
# # Resume Clasifier Based On Random Forest Classifier
#
# **OVERVIEW :**
#
# 1. **Impoert Relevent modules and load the Dataset**
#
# 2. **Did small Preprocess to the text in the dataset**
#
# 3. **Did an Exploratory Data Analysis to getting a visual understanding about the dataset**
# 4. **Then Performe data cleaning and vectorizer the resume text using CountVectorizer**
# 5. **Then used gridSearch to finding optimal values for the Random Forest Classifier model**
# 6. **Finally, Train the model and analyze the accuraccy scores.**
#
#
#
# **We Also can use a LSTM based Deep Learning model for this classification as well. Refere this Notebook of mine** - https://www.kaggle.com/code/sanchukanirupama/lstm-based-fake-news-detection

# %% [markdown]
# # **Importing Modules**

# %%
# !pip install nltk
# !pip install gensim
# !pip install wordcloud
# Out:
# Requirement already satisfied: nltk in c:\users\akshat~1\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\akshat~1\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\akshat~1\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\akshat~1\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\akshat~1\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\akshat~1\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: gensim in c:\users\akshat~1\anaconda3\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\akshat~1\anaconda3\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\akshat~1\anaconda3\lib\site-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\akshat~1\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: wordcloud in c:\users\akshat~1\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\akshat~1\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\akshat~1\anaconda3\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\akshat~1\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\akshat~1\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\akshat~1\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import gensim
import re
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv(r"D:\4Week-4Project_Challenge\Resume_Analyzer\data\Resume.csv")
df.head()
# Out:
#          ID                                         Resume_str  \
# 0  16852973           HR ADMINISTRATOR/MARKETING ASSOCIATE\...
# 1  22323967           HR SPECIALIST, US HR OPERATIONS      ...
# 2  33176873           HR DIRECTOR       Summary      Over 2...
# 3  27018550           HR SPECIALIST       Summary    Dedica...
# 4  17812897           HR MANAGER         Skill Highlights  ...
#
#                                          Resume_html Category
# 0  <div class="fontsize fontface vmargins hmargin...       HR
# 1  <div class="fontsize fontface vmargins hmargin...       HR
# 2  <div class="fontsize fontface vmargins hmargin...       HR
# 3  <div class="fontsize fontface vmargins hmargin...       HR
# 4  <div class="fontsize fontface vmargins hmargin...       HR

# %%
# drop not using columns
df.drop(columns = ['ID', 'Resume_html'], inplace = True)
df
# Out:
#                                              Resume_str  Category
# 0              HR ADMINISTRATOR/MARKETING ASSOCIATE\...        HR
# 1              HR SPECIALIST, US HR OPERATIONS      ...        HR
# 2              HR DIRECTOR       Summary      Over 2...        HR
# 3              HR SPECIALIST       Summary    Dedica...        HR
# 4              HR MANAGER         Skill Highlights  ...        HR
# ...                                                 ...       ...
# 2479           RANK: SGT/E-5 NON- COMMISSIONED OFFIC...  AVIATION
# 2480           GOVERNMENT RELATIONS, COMMUNICATIONS ...  AVIATION
# 2481           GEEK SQUAD AGENT         Professional...  AVIATION
# 2482           PROGRAM DIRECTOR / OFFICE MANAGER    ...  AVIATION
# 2483           STOREKEEPER II       Professional Sum...  AVIATION
#
# [2484 rows x 2 columns]

# %% [markdown]
# # **Data Preprocessing**

# %%
STOPWORDS = set(stopwords.words('english'))
STEMMER = PorterStemmer()

def preprocess(txt):
    txt = txt.lower()
    txt = re.sub('[^a-zA-Z]', ' ', txt)
    txt = nltk.tokenize.word_tokenize(txt)
    txt = [w for w in txt if w not in STOPWORDS]
    txt = [STEMMER.stem(w) for w in txt]
    return ' '.join(txt)

# %%
df['Resume'] = df['Resume_str'].apply(lambda w: preprocess(w))
# drop original text column
df.pop('Resume_str')
df
# Out:
#       Category                                             Resume
# 0           HR  hr administr market associ hr administr summar...
# 1           HR  hr specialist us hr oper summari versatil medi...
# 2           HR  hr director summari year experi recruit plu ye...
# 3           HR  hr specialist summari dedic driven dynam year ...
# 4           HR  hr manag skill highlight hr skill hr depart st...
# ...        ...                                                ...
# 2479  AVIATION  rank sgt e non commiss offic charg brigad mail...
# 2480  AVIATION  govern relat commun organiz develop director p...
# 2481  AVIATION  geek squad agent profession profil support spe...
# 2482  AVIATION  program director offic manag summari highli pe...
# 2483  AVIATION  storekeep ii profession summari purpos documen...
#
# [2484 rows x 2 columns]

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  2484 non-null   object
#  1   Resume    2484 non-null   object
# dtypes: object(2)
# memory usage: 38.9+ KB

# %%
df['Category'].value_counts()
# Out:
# Category
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# FINANCE                   118
# ADVOCATE                  118
# ACCOUNTANT                118
# ENGINEERING               118
# CHEF                      118
# AVIATION                  117
# FITNESS                   117
# SALES                     116
# BANKING                   115
# HEALTHCARE                115
# CONSULTANT                115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: count, dtype: int64

# %%
df['Category'].value_counts().sort_index().plot(kind='bar', figsize=(12, 6))
plt.show()

# %%
from matplotlib.gridspec import GridSpec
count=df['Category'].value_counts()
label=df['Category'].value_counts().keys()

plt.figure(1, figsize=(25,25))
grid=GridSpec(2,2)

cmap=plt.get_cmap('coolwarm')

color=[cmap(i) for i in np.linspace(0, 1, 5)]
plt.subplot(grid[0,1], aspect=1, title='Distribution')

pie=plt.pie(count, labels=label, autopct='%1.2f%%')
plt.show()

# %%
# create list of all categories
categories = np.sort(df['Category'].unique())
categories
# Out:
# array(['ACCOUNTANT', 'ADVOCATE', 'AGRICULTURE', 'APPAREL', 'ARTS',
#        'AUTOMOBILE', 'AVIATION', 'BANKING', 'BPO', 'BUSINESS-DEVELOPMENT',
#        'CHEF', 'CONSTRUCTION', 'CONSULTANT', 'DESIGNER', 'DIGITAL-MEDIA',
#        'ENGINEERING', 'FINANCE', 'FITNESS', 'HEALTHCARE', 'HR',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'SALES', 'TEACHER'],
#       dtype=object)

# %%
# create new df for corpus and category
df_categories = [df[df['Category'] == category].loc[:, ['Resume', 'Category']] for category in categories]
df_categories[10]
# Out:
#                                                  Resume Category
# 1357  chef career focu nurs student recent obtain cn...     CHEF
# 1358  chef summari custom orient fast food worker de...     CHEF
# 1359  chef career overview dedic custom servic repre...     CHEF
# 1360  chef summari experienc cater chef skill prepar...     CHEF
# 1361  rm roxann mejia summari motiv chef compet keep...     CHEF
# ...                                                 ...      ...
# 1470  owner chef summari chef year critic acclaim wo...     CHEF
# 1471  kindergarten teacher profession summari energe...     CHEF
# 1472  substitut para profession summari profession m...     CHEF
# 1473  execut chef partner summari proven abil fine d...     CHEF
# 1474  line chef expedit summari chef year experi coo...     CHEF
#
# [118 rows x 2 columns]

# %%
# word frequency for each category
def wordfreq(df):
    count = df['Resume'].str.split(expand=True).stack().value_counts().reset_index()
    count.columns = ['Word', 'Frequency']

    return count.head(10)

# %%
fig = plt.figure(figsize=(32, 64))

for i, category in enumerate(np.sort(df['Category'].unique())):
    wf = wordfreq(df_categories[i])

    fig.add_subplot(12, 2, i + 1).set_title(category)
    plt.bar(wf['Word'], wf['Frequency'])
    plt.ylim(0, 3500)

plt.show()
plt.close()

# %% [markdown]
# # **Data Cleaning**

# %%
nltk.download("punkt")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\AKSHAT
# [nltk_data]     KULKARNI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\AKSHAT
# [nltk_data]     KULKARNI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
#defining stopwords
stop_words = stopwords.words('english')

# %%
#function which stop words and the words less than 2 characters
def remove_stop_words (text):
  result = []
  for token in gensim.utils.simple_preprocess(text):
    if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3 and token not in stop_words:
      result.append(token)

  return result

# %%
df['clean'] = df['Resume'].apply(remove_stop_words).astype(str)

# %%
df['clean'][0]
# Out:
# "['administr', 'market', 'associ', 'administr', 'summari', 'dedic', 'custom', 'servic', 'manag', 'year', 'experi', 'hospit', 'custom', 'servic', 'manag', 'respect', 'builder', 'leader', 'custom', 'focus', 'team', 'strive', 'instil', 'share', 'enthusiast', 'commit', 'custom', 'servic', 'highlight', 'focus', 'custom', 'satisfact', 'team', 'manag', 'market', 'savvi', 'conflict', 'resolut', 'techniqu', 'train', 'develop', 'skill', 'multi', 'tasker', 'client', 'relat', 'specialist', 'accomplish', 'missouri', 'supervisor', 'train', 'certif', 'certifi', 'custom', 'loyalti', 'market', 'segment', 'hilton', 'worldwid', 'gener', 'manag', 'train', 'certif', 'accomplish', 'trainer', 'cross', 'server', 'hospit', 'hilton', 'micro', 'opera', 'fidelio', 'opera', 'reserv', 'holidex', 'complet', 'cours', 'seminar', 'custom', 'servic', 'sale', 'strategi', 'inventori', 'control', 'loss', 'prevent', 'safeti', 'time', 'manag', 'leadership', 'perform', 'assess', 'experi', 'administr', 'market', 'associ', 'administr', 'current', 'compani', 'citi', 'state', 'help', 'develop', 'polici', 'direct', 'coordin', 'activ', 'employ', 'compens', 'labor', 'relat', 'benefit', 'train', 'employe', 'servic', 'prepar', 'employe', 'separ', 'notic', 'relat', 'document', 'record', 'benefit', 'plan', 'particip', 'insur', 'pension', 'plan', 'personnel', 'transact', 'hire', 'promot', 'transfer', 'perform', 'review', 'termin', 'employe', 'statist', 'govern', 'report', 'advis', 'manag', 'appropri', 'resolut', 'employe', 'relat', 'issu', 'administ', 'benefit', 'program', 'life', 'health', 'dental', 'insur', 'pension', 'plan', 'vacat', 'sick', 'leav', 'leav', 'absenc', 'employe', 'assist', 'market', 'associ', 'design', 'creat', 'market', 'collater', 'sale', 'meet', 'trade', 'compani', 'execut', 'manag', 'hous', 'advertis', 'program', 'consist', 'print', 'media', 'collater', 'piec', 'assist', 'complet', 'design', 'launch', 'compani', 'websit', 'month', 'creat', 'offici', 'compani', 'page', 'facebook', 'facilit', 'interact', 'custom', 'analyz', 'rate', 'program', 'featur', 'competitor', 'evalu', 'effect', 'market', 'strategi', 'advanc', 'medic', 'claim', 'analyst', 'compani', 'citi', 'state', 'review', 'medic', 'accuraci', 'treatment', 'test', 'hospit', 'stay', 'prior', 'sanction', 'claim', 'train', 'interpret', 'code', 'terminolog', 'commonli', 'medic', 'fulli', 'understand', 'paperwork', 'submit', 'healthcar', 'provid', 'requir', 'organiz', 'analyt', 'skill', 'comput', 'skill', 'knowledg', 'medic', 'terminolog', 'procedur', 'statist', 'standard', 'data', 'analysi', 'regard', 'medic', 'assist', 'gener', 'manag', 'compani', 'citi', 'state', 'perform', 'duti', 'includ', 'limit', 'budget', 'financi', 'manag', 'account', 'human', 'resourc', 'payrol', 'purchas', 'establish', 'maintain', 'close', 'work', 'relationship', 'depart', 'hotel', 'ensur', 'maximum', 'oper', 'product', 'moral', 'guest', 'servic', 'handl', 'daili', 'oper', 'report', 'directli', 'corpor', 'offic', 'hire', 'train', 'staff', 'overal', 'object', 'goal', 'emphasi', 'high', 'custom', 'servic', 'market', 'advertis', 'work', 'public', 'relat', 'media', 'govern', 'local', 'busi', 'chamber', 'commerc', 'execut', 'support', 'market', 'assist', 'compani', 'citi', 'state', 'provid', 'assist', 'variou', 'depart', 'head', 'execut', 'market', 'custom', 'servic', 'human', 'resourc', 'manag', 'oper', 'ensur', 'friendli', 'effici', 'transact', 'ensur', 'swift', 'resolut', 'custom', 'issu', 'preserv', 'custom', 'loyalti', 'compli', 'compani', 'polici', 'exemplifi', 'second', 'custom', 'servic', 'deliveri', 'interact', 'custom', 'potenti', 'client', 'reserv', 'offic', 'manag', 'compani', 'citi', 'state', 'owner', 'partner', 'compani', 'citi', 'state', 'price', 'integr', 'coordin', 'compani', 'citi', 'state', 'educ', 'busi', 'administr', 'jefferson', 'colleg', 'citi', 'state', 'busi', 'administr', 'market', 'advertis', 'high', 'school', 'diploma', 'colleg', 'prep', 'studi', 'saint', 'geneviev', 'senior', 'high', 'citi', 'state', 'aw ...

# %%
df
# Out:
#       Category                                             Resume  \
# 0           HR  hr administr market associ hr administr summar...
# 1           HR  hr specialist us hr oper summari versatil medi...
# 2           HR  hr director summari year experi recruit plu ye...
# 3           HR  hr specialist summari dedic driven dynam year ...
# 4           HR  hr manag skill highlight hr skill hr depart st...
# ...        ...                                                ...
# 2479  AVIATION  rank sgt e non commiss offic charg brigad mail...
# 2480  AVIATION  govern relat commun organiz develop director p...
# 2481  AVIATION  geek squad agent profession profil support spe...
# 2482  AVIATION  program director offic manag summari highli pe...
# 2483  AVIATION  storekeep ii profession summari purpos documen...
#
#                                                   clean
# 0     ['administr', 'market', 'associ', 'administr',...
# 1     ['specialist', 'oper', 'summari', 'versatil', ...
# 2     ['director', 'summari', 'year', 'experi', 'rec...
# 3     ['specialist', 'summari', 'dedic', 'driven', '...
# 4     ['manag', 'skill', 'highlight', 'skill', 'depa...
# ...                                                 ...
# 2479  ['rank', 'commiss', 'offic', 'charg', 'brigad'...
# 2480  ['govern', 'relat', 'commun', 'organiz', 'deve...
# 2481  ['geek', 'squad', 'agent', 'profession', 'prof...
# 2482  ['program', 'director', 'offic', 'manag', 'sum...
# 2483  ['storekeep', 'profession', 'summari', 'purpos...
#
# [2484 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df['clean'], df['Category'], test_size = 0.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# vectorize text data
vectorizer = CountVectorizer()
conuntvectorizer_train = vectorizer.fit_transform(X_train).astype(float)
conuntvectorizer_test = vectorizer.transform(X_test).astype(float)

# %% [markdown]
# # **Model Training**

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [None, 5, 10, 15],
    'max_features': ['sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}

rand_search = RandomizedSearchCV(
    estimator=RFC,
    param_distributions=param_dist,
    n_iter=10,        # only test 10 combos instead of 60
    cv=5,
    scoring='accuracy',
    random_state=42,
    verbose=1
)

rand_search.fit(conuntvectorizer_train, Y_train)
print(rand_search.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# {'n_estimators': 100, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import joblib
import os
import numpy as np
from sklearn.ensemble import RandomForestClassifier

best_params = rand_search.best_params_
print("Best Parameters:", best_params)

RF_Model = RandomForestClassifier(
    random_state=42,
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    max_features=best_params['max_features'],
    criterion=best_params['criterion']
)

RF_Model.fit(conuntvectorizer_train, Y_train)
# Out:
# Best Parameters: {'n_estimators': 100, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# RandomForestClassifier(random_state=42)

# %%
prediction = RF_Model.predict(conuntvectorizer_test)
prediction
# Out:
# array(['CHEF', 'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'HR',
#        'DIGITAL-MEDIA', 'APPAREL', 'PUBLIC-RELATIONS', 'PUBLIC-RELATIONS',
#        'DESIGNER', 'AVIATION', 'CONSULTANT', 'BANKING', 'HR', 'ADVOCATE',
#        'BUSINESS-DEVELOPMENT', 'PUBLIC-RELATIONS', 'CHEF', 'BANKING',
#        'ACCOUNTANT', 'DIGITAL-MEDIA', 'AVIATION', 'BUSINESS-DEVELOPMENT',
#        'TEACHER', 'SALES', 'FITNESS', 'PUBLIC-RELATIONS',
#        'INFORMATION-TECHNOLOGY', 'BUSINESS-DEVELOPMENT',
#        'INFORMATION-TECHNOLOGY', 'DESIGNER', 'ACCOUNTANT', 'TEACHER',
#        'SALES', 'HEALTHCARE', 'DESIGNER', 'HR', 'ENGINEERING', 'ADVOCATE',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'ENGINEERING', 'FINANCE',
#        'FITNESS', 'TEACHER', 'SALES', 'ADVOCATE', 'TEACHER', 'TEACHER',
#        'FINANCE', 'CHEF', 'FITNESS', 'CHEF', 'ENGINEERING', 'ACCOUNTANT',
#        'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'SALES', 'BANKING',
#        'FITNESS', 'INFORMATION-TECHNOLOGY', 'FINANCE', 'DIGITAL-MEDIA',
#        'PUBLIC-RELATIONS', 'PUBLIC-RELATIONS', 'ADVOCATE', 'CHEF',
#        'SALES', 'AVIATION', 'FITNESS', 'HEALTHCARE', 'CONSTRUCTION',
#        'ENGINEERING', 'CONSTRUCTION', 'PUBLIC-RELATIONS', 'TEACHER',
#        'CONSTRUCTION', 'ADVOCATE', 'AVIATION', 'SALES', 'CONSTRUCTION',
#        'BANKING', 'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'TEACHER',
#        'TEACHER', 'CHEF', 'FITNESS', 'CHEF', 'CHEF',
#        'INFORMATION-TECHNOLOGY', 'AVIATION', 'HEALTHCARE',
#        'DIGITAL-MEDIA', 'ENGINEERING', 'BUSINESS-DEVELOPMENT',
#        'ACCOUNTANT', 'FITNESS', 'BANKING', 'DESIGNER', 'ENGINEERING',
#        'FITNESS', 'INFORMATION-TECHNOLOGY', 'AGRICULTURE',
#        'PUBLIC-RELATIONS', 'INFORMATION-TECHNOLOGY', 'SALES',
#        'INFORMATION-TECHNOLOGY', 'ACCOUNTANT', 'HEALTHCARE',
#        'PUBLIC-RELATIONS', 'AVIATION', 'CONSTRUCTION', 'DIGITAL-MEDIA',
#        'ACCOUNTANT', 'PUBLIC-RELATIONS', 'PUBLIC-RELATIONS',
#        'BUSINESS-DEVELOPMENT', 'CONSTRUCTION', 'PUBLIC-RELATIONS',
#        'HEALTHCARE', 'INFORMATION-TECHNOLOGY', 'HEALTHCARE', 'BANKING',
#        'BANKING', 'HEALTHCARE', 'BUSINESS-DEVELOPMENT', 'BANKING',
#        'CONSTRUCTION', 'BUSINESS-DEVELOPMENT', 'HEALTHCARE', 'ADVOCATE',
#        'CONSTRUCTION', 'AVIATION', 'DIGITAL-MEDIA', 'DESIGNER', 'FINANCE',
#        'HR', 'TEACHER', 'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY',
#        'DESIGNER', 'INFORMATION-TECHNOLOGY', 'APPAREL', 'TEACHER',
#        'FITNESS', 'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'CHEF', 'ADVOCATE',
#        'ACCOUNTANT', 'ADVOCATE', 'HR', 'DESIGNER', 'HR', 'ADVOCATE',
#        'FINANCE', 'ADVOCATE', 'ADVOCATE', 'BANKING', 'PUBLIC-RELATIONS',
#        'TEACHER', 'BUSINESS-DEVELOPMENT', 'HEALTHCARE', 'APPAREL',
#        'ENGINEERING', 'HR', 'HEALTHCARE', 'SALES', 'ACCOUNTANT',
#        'TEACHER', 'DIGITAL-MEDIA', 'TEACHER', 'ENGINEERING',
#        'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'CONSTRUCTION', 'ADVOCATE',
#        'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'TEACHER', 'AVIATION',
#        'TEACHER', 'TEACHER', 'ADVOCATE', 'CONSULTANT', 'TEACHER',
#        'PUBLIC-RELATIONS', 'HEALTHCARE', 'ACCOUNTANT', 'FITNESS', 'SALES',
#        'DIGITAL-MEDIA', 'BANKING', 'SALES', 'CONSTRUCTION',
#        'DIGITAL-MEDIA', 'HEALTHCARE', 'CHEF', 'DIGITAL-MEDIA',
#        'ACCOUNTANT', 'BANKING', 'HEALTHCARE', 'ACCOUNTANT', 'SALES',
#        'ACCOUNTANT', 'FINANCE', 'PUBLIC-RELATIONS', 'FITNESS',
#        'ACCOUNTANT', 'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY',
#        'AVIATION', 'AVIATION', 'BANKING', 'DESIGNER',
#        'INFORMATION-TECHNOLOGY', 'BANKING', 'FITNESS', 'FITNESS',
#        'PUBLIC-RELATIONS', 'CHEF', 'INFORMATION-TECHNOLOGY', 'BANKING',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY',
#        'BUSINESS-DEVELOPMENT', 'FINANCE', 'TEACHER', 'FINANCE',
#        'ACCOUNTANT', 'PUBLIC-RELATIONS', 'SALES', 'DIGITAL-MEDIA',
#        'AVIATION', 'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'BANKING',
#        'BANKING', 'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'CHEF',
#        'ENGINEERING', 'ENGINEERING', 'DIGITAL-MEDIA', 'CONSTRUCTION',
#        'ENGINEERING', 'PUBLIC-RELATIONS', 'SALES', 'ENGINEERING',
#        'CONSTRUCTION', 'BUSINESS-DEVELOPMENT', 'ACCOUNTANT', 'HEALTHCARE',
#        'DIGITAL-MEDIA', 'SALES', 'ENGINEERING', 'HR', 'TEACHER',
#        'APPAREL', 'SALES', 'CHEF', 'TEACHER', 'HEALTHCARE', 'FINANCE',
#        'SALES', 'HR', 'AVIATION', 'ENGINEERING', 'FINANCE', 'TEACHER',
#        'INFORMATION-TECHNOLOGY', 'AVIATION', 'HR', 'DIGITAL-MEDIA',
#        'INFORMATION-TECHNOLOGY', 'BUSINESS-DEVELOPMENT', 'CONSULTANT',
#        'FITNESS', 'HR', 'FITNESS', 'SALES', 'CHEF', 'TEACHER',
#        'BUSINESS-DEVELOPMENT', 'HR', 'CONSULTANT', 'ADVOCATE',
#        'PUBLIC-RELATIONS', 'APPAREL', 'BANKING', 'SALES', 'TEACHER',
#        'BANKING', 'DIGITAL-MEDIA', 'TEACHER', 'ARTS', 'ACCOUNTANT',
#        'ACCOUNTANT', 'CONSTRUCTION', 'SALES', 'CONSTRUCTION',
#        'ACCOUNTANT', 'SALES', 'BUSINESS-DEVELOPMENT', 'CHEF',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'APPAREL', 'TEACHER',
#        'PUBLIC-RELATIONS', 'BUSINESS-DEVELOPMENT', 'ADVOCATE', 'CHEF',
#        'DIGITAL-MEDIA', 'ENGINEERING', 'AVIATION', 'BUSINESS-DEVELOPMENT',
#        'HEALTHCARE', 'AVIATION', 'CHEF', 'AVIATION', 'CHEF',
#        'DIGITAL-MEDIA', 'APPAREL', 'BANKING', 'HR', 'HEALTHCARE',
#        'HEALTHCARE', 'SALES', 'CHEF', 'ENGINEERING',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'BUSINESS-DEVELOPMENT',
#        'AVIATION', 'BUSINESS-DEVELOPMENT', 'ADVOCATE', 'SALES', 'CHEF',
#        'HR', 'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'SALES', 'CHEF',
#        'TEACHER', 'INFORMATION-TECHNOLOGY', 'CONSTRUCTION', 'TEACHER',
#        'TEACHER', 'CHEF', 'CHEF', 'FITNESS', 'CHEF', 'ADVOCATE',
#        'INFORMATION-TECHNOLOGY', 'HEALTHCARE', 'TEACHER', 'HR',
#        'HEALTHCARE', 'DIGITAL-MEDIA', 'SALES', 'TEACHER', 'CONSTRUCTION',
#        'DESIGNER', 'ADVOCATE', 'FINANCE', 'CONSTRUCTION', 'DIGITAL-MEDIA',
#        'ACCOUNTANT', 'CONSTRUCTION', 'CONSTRUCTION',
#        'INFORMATION-TECHNOLOGY', 'TEACHER', 'CHEF',
#        'INFORMATION-TECHNOLOGY', 'FINANCE', 'ENGINEERING', 'ENGINEERING',
#        'ACCOUNTANT', 'DESIGNER', 'BUSINESS-DEVELOPMENT', 'HR',
#        'ACCOUNTANT', 'CHEF', 'DESIGNER', 'TEACHER', 'APPAREL',
#        'HEALTHCARE', 'HR', 'ARTS', 'INFORMATION-TECHNOLOGY', 'BANKING',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'CHEF', 'HR',
#        'FITNESS', 'FITNESS', 'TEACHER', 'TEACHER', 'HR', 'CHEF',
#        'CONSTRUCTION', 'TEACHER', 'PUBLIC-RELATIONS',
#        'BUSINESS-DEVELOPMENT', 'INFORMATION-TECHNOLOGY', 'AVIATION',
#        'CHEF', 'HEALTHCARE', 'TEACHER', 'HEALTHCARE', 'TEACHER',
#        'ENGINEERING', 'BUSINESS-DEVELOPMENT', 'AGRICULTURE',
#        'BUSINESS-DEVELOPMENT', 'BANKING', 'BUSINESS-DEVELOPMENT',
#        'ADVOCATE', 'BUSINESS-DEVELOPMENT', 'AVIATION', 'APPAREL',
#        'FINANCE', 'HR', 'APPAREL', 'DESIGNER', 'SALES', 'ENGINEERING',
#        'DESIGNER', 'AVIATION', 'BUSINESS-DEVELOPMENT', 'CONSTRUCTION',
#        'BANKING', 'ACCOUNTANT', 'ENGINEERING', 'BANKING', 'FITNESS',
#        'HEALTHCARE', 'PUBLIC-RELATIONS', 'FINANCE', 'DESIGNER',
#        'DIGITAL-MEDIA', 'ENGINEERING', 'ACCOUNTANT', 'TEACHER',
#        'DIGITAL-MEDIA', 'CONSTRUCTION', 'AVIATION', 'BANKING', 'BANKING',
#        'CONSTRUCTION', 'HEALTHCARE', 'AVIATION', 'DIGITAL-MEDIA', 'HR',
#        'INFORMATION-TECHNOLOGY', 'ADVOCATE', 'FITNESS', 'SALES',
#        'TEACHER', 'DESIGNER', 'CONSTRUCTION', 'INFORMATION-TECHNOLOGY',
#        'SALES', 'AVIATION', 'HEALTHCARE', 'AVIATION',
#        'INFORMATION-TECHNOLOGY', 'PUBLIC-RELATIONS', 'CHEF', 'HEALTHCARE',
#        'DIGITAL-MEDIA', 'AVIATION', 'DESIGNER', 'FITNESS', 'APPAREL',
#        'INFORMATION-TECHNOLOGY', 'INFORMATION-TECHNOLOGY', 'HEALTHCARE',
#        'DESIGNER', 'AVIATION', 'FINANCE', 'CHEF', 'ENGINEERING',
#        'TEACHER', 'AVIATION', 'BANKING', 'ARTS', 'ACCOUNTANT', 'ADVOCATE',
#        'HR', 'AVIATION', 'DESIGNER', 'ACCOUNTANT', 'BUSINESS-DEVELOPMENT',
#        'AVIATION'], dtype=object)

# %%
print("Training Score: {:.2f}".format(RF_Model.score(conuntvectorizer_train, Y_train)))
print("Test Score: {:.2f}".format(RF_Model.score(conuntvectorizer_test, Y_test)))
# Out:
# Training Score: 1.00
# Test Score: 0.60

# %%
print("Model Report:\n")
print(metrics.classification_report(Y_test, prediction))
# Out:
# Model Report:
#
#                         precision    recall  f1-score   support
#
#             ACCOUNTANT       0.54      0.94      0.68        16
#               ADVOCATE       0.65      0.60      0.62        25
#            AGRICULTURE       1.00      0.14      0.25        14
#                APPAREL       0.55      0.38      0.44        16
#                   ARTS       0.67      0.07      0.12        30
#             AUTOMOBILE       0.00      0.00      0.00         4
#               AVIATION       0.83      0.75      0.79        32
#                BANKING       0.46      0.67      0.55        18
#                    BPO       0.00      0.00      0.00         7
#   BUSINESS-DEVELOPMENT       0.67      0.62      0.65        32
#                   CHEF       0.68      0.81      0.74        26
#           CONSTRUCTION       0.70      0.76      0.73        25
#             CONSULTANT       0.75      0.15      0.25        20
#               DESIGNER       0.61      0.61      0.61        18
#          DIGITAL-MEDIA       0.65      0.62      0.64        24
#            ENGINEERING       0.48      0.61      0.54        18
#                FINANCE       0.73      0.73      0.73        15
#                FITNESS       0.67      0.52      0.58        27
#             HEALTHCARE       0.50      0.64      0.56        22
#                     HR       0.64      0.88      0.74        16
# INFORMATION-TECHNOLOGY       0.54      0.84      0.66        25
#       PUBLIC-RELATIONS       0.58      0.78      0.67        18
#                  SALES       0.52      0.47      0.49        30
#                TEACHER       0.42      0.95      0.58        19
#
#               accuracy                           0.60       497
#              macro avg       0.58      0.56      0.53       497
#           weighted avg       0.62      0.60      0.56       497
# C:\Users\AKSHAT KULKARNI\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\AKSHAT KULKARNI\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\AKSHAT KULKARNI\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **Always wellcome any Improvements that you can suggest. Thank You !!**

# %%
os.makedirs("../model", exist_ok=True)

# Save trained model
joblib.dump(RF_Model, "../model/resume_classifier_model.joblib")

# Save vectorizer
joblib.dump(vectorizer, "../model/vectorizer.joblib")

# Save label classes
labels = np.unique(Y_train)
joblib.dump(labels, "../model/label_classes.joblib")

print("Model, vectorizer, and labels saved successfully!")
# Out:
# Model, vectorizer, and labels saved successfully!
